# %%
# %cd drive/MyDrive/18786\ Project
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/18786 Project'
# /content

# %%
from google.colab import drive
drive.mount('https://drive.google.com/drive/folders/1cAXtTGNGEGbsgpigPVp6YhzpltJeV2OA?usp=drive_link')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-a8da165081cc> in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('https://drive.google.com/drive/folders/1cAXtTGNGEGbsgpigPVp6YhzpltJeV2OA?usp=drive_link')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     202     normed = _os.path.normpath(mountpoint)
# ...

# %%
# !pip install -r requirements.txt

# %%
# !python3 src/train.py
# Out:
# python3: can't open file '/content/drive/MyDrive/18786 Project/src/train.py': [Errno 2] No such file or directory
